-- %% [markdown]
-- # TODO

-- %%
let myList = [1, 2, 3, 4, 5]

-- %%
:t foldl
-- Out:
-- foldl :: forall (t :: * -> *) b a. Foldable t => (b -> a -> b) -> b -> t a -> b

-- %%
foldl (\x y -> y : x) [] myList
-- Out:
-- Line 1: Avoid lambda
-- Found:
-- \ x y -> y : x
-- Why not:
-- flip (:)
-- [5,4,3,2,1]

-- %%
:t foldr
-- Out:
-- foldr :: forall (t :: * -> *) a b. Foldable t => (a -> b -> b) -> b -> t a -> b

-- %%
foldr (\x y -> x : y) [] myList
-- Out:
-- Line 1: Use map
-- Found:
-- foldr (\ x y -> x : y) []
-- Why not:
-- map (\ x -> x)Line 1: Avoid lambda
-- Found:
-- \ x y -> x : y
-- Why not:
-- (:)
-- [1,2,3,4,5]

-- %%
headOr = foldr const

-- %%
:t headOr
-- Out:
-- headOr :: forall (t :: * -> *) b. Foldable t => b -> t b -> b

-- %%
headOr 1 []
-- Out:
-- 1

-- %%
foldr (\x y -> x) 0 [1]
-- Out:
-- Line 1: Use const
-- Found:
-- \ x y -> x
-- Why not:
-- const
-- 1

-- %%
flip (foldl (const . succ)) [1, 2,3] 0
-- Out:
-- Line 1: Redundant flip
-- Found:
-- flip (foldl (const . succ)) [1, 2, 3] 0
-- Why not:
-- foldl (const . succ) 0 [1, 2, 3]
-- 3
